# %%
# Install dependencies
# !pip install happytransformer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 45 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 5.3 MB 49.4 MB/s
# ...
#      |████████████████████████████████| 441 kB 62.2 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 58.9 MB/s
# ...
#      |████████████████████████████████| 212 kB 63.8 MB/s
# ...
#      |████████████████████████████████| 163 kB 58.6 MB/s
# ...
#      |████████████████████████████████| 115 kB 72.8 MB/s
# ...
#      |████████████████████████████████| 127 kB 69.1 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 60.9 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# Import libraries
from happytransformer import HappyGeneration
from happytransformer import GENTrainArgs
from happytransformer import GENSettings

# %%
# Create a HappyGeneration Object
happy_gen = HappyGeneration("GPT-NEO", "EleutherAI/gpt-neo-125M")
# Out:
# Downloading:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/526M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/560 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/357 [00:00<?, ?B/s]

# %%
# Train the model
args = GENTrainArgs(num_train_epochs=1)
happy_gen.train("/content/drive/MyDrive/abcnews-date-text.csv", args=args)
# Out:
# WARNING:datasets.builder:Using custom data configuration default-29f40be55778ceca
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-29f40be55778ceca/0.0.0/21a506d1b2b34316b1e82d0bd79066905d846e5d7e619823c0dd338d6f1fa6ad. Subsequent calls will reuse this data.
# ...
#   0%|          | 0/1049 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 3546
#   Num Epochs = 1
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
#   Gradient Accumulation steps = 1
# ...

# %% [markdown]
# Results

# %%
args = GENSettings(no_repeat_ngram_size=2)

# %%
top_k_sampling_settings = GENSettings(do_sample=True, early_stopping=False, top_k=50, temperature=0.7)

# %%
result = happy_gen.generate_text("Elon Musk tried to buy Twitter on September 2020", args=args)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
# Output 1
print(result.text)
# Out:
# nasa to probe space station failurenats to get new space shuttle to be built in nswnato to launch new satellite to help solve space mysterynth to vote on new constitutionnsw to introduce new laws to combat terrorismnurses to

# %%
result = happy_gen.generate_text("Elon Musk  face deposition by Twitter lawyers ahead of trial", args=top_k_sampling_settings)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
# Output 2
print(result.text)
# Out:
# mackay man charged after violent home invasionmatthewson rejects calls for more police presencematthewson dismisses call for more police in themichael mccartney warns against child abuse claimsmcguire on the riseminister says

# %%
result = happy_gen.generate_text("ETwitters relationship with Musk has been a rocky one",args=args)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
# Output 3
print(result.text)
# Out:
#  for yearswet weather for the south west westwilcannia to be released from hospital after being hit by carwoolworths to sell off its assets to buywomens first test squad to play in wwswift to

# %%
result = happy_gen.generate_text("Musk and his billionaire buddies discussing plans for Twitter",args=args)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
# Output 4
print(result.text)
# Out:
# kalgoorlie council to consider new councilkohler to be quizzed over newcastle council planskookaburras to get new stadiumkyrgios to face court over alleged assaultkurdish rebels to fight in iraq

# %%
result = happy_gen.generate_text("Air India returns to Tata home after 69 yrs",args=args)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
# Output 5
print(result.text)
# Out:
#  of damage from fire in nt police stationkalgoorlie council to consider new council landkangaroo island residents to get say on future of kangarooskatherine residents urged to be prepared for fire threatkimberley council
